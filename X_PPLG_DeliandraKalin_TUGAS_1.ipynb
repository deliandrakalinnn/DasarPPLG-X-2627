# %% [markdown]
# <a href="https://colab.research.google.com/github/deliandrakalinnn/DasarPPLG-X-2627/blob/main/X_PPLG_DeliandraKalin_TUGAS_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TUGAS 1 PRAKTIK TUGAS MAMBUAT TIPE DATA DAN VARIABEL
#
# Nama Kelompok: Nova crew
#
# 1.Azril Ramadhan Sonda 2.C.Afra Naila Zainiati 3.Deliandra Kalin 4.Dava Muklis Saputra 5.Muhammad Adikamedian Putra 6.Raffa Maulana Irawan 7.Rizky Savario Zaki Putra

# %%
# !g++ --version
# Out:
# g++ (Ubuntu 13.3.0-6ubuntu2~24.04.1) 13.3.0
# Copyright (C) 2023 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# %%writefile input_data.cpp
# #include <iostream>
# #include <string>
# using namespace std;
#
# int main() {
#    string namaSiswa;
#    int umur;
#
#    cout << "Masukkan Nama (1 Kata) : ";
#    cin >> namaSiswa;
#
#    cout << "Masukkan Umur Anda     : ";
#    cin >> umur;
#
#    cout << "\nHalo " << namaSiswa << ", ternyata umur kamu " << umur << " tahun ya!" << endl;
#    return 0;
# }
# Out:
# Overwriting input_data.cpp

# %%
# !g++ input_data.cpp -o input_data
# !./input_data
# Out:
# Masukkan Nama (1 Kata) : ^C
