# %% [markdown]
# <a href="https://colab.research.google.com/github/deliandrakalinnn/DasarPPLG-X-2627/blob/main/x_pplg_deliandrakalin_tugas_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TUGAS 1 PRAKTIK TUGAS  MAMBUAT TIPE DATA DAN VARIABEL
#
# Nama Kelompok: Nova crew
#
# 1.Azril Ramadhan Sonda
# 2.C.Afra Naila Zainiati
# 3.Deliandra Kalin
# 4.Dava Muklis Saputra
# 5.Muhammad Adikamedian Putra
# 6.Raffa Maulana Irawan
# 7.Rizky Savario Zaki Putra

# %%
# !g++ --version
# Out:
# g++ (Ubuntu 13.3.0-6ubuntu2~24.04.1) 13.3.0
# Copyright (C) 2023 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# %%writefile praktik_variabel.cpp
# #include <iostream>
# #include <string>
# using namespace std;
#
# int main() {
# //Deklarasi Variabel dan Tipe Data
# string namaBarang = "Laptop Hp";
# int jumlah       = 2;
# float harga      = 750000.50;
# char kategori    = 'A';
# bool tersedia    = true;
#
# //menampilkan output ke layar
# cout << "=== DATA INVENTARIS===" <<endl;
# cout << "namaBarang  :" << namaBarang << endl;
# cout << "Kategori    :" << kategori << endl;
# cout << "jumlah      :" << jumlah << endl;
# cout << "harga       :Rp" << harga << endl;
# cout << "Tersedia    :" <<tersedia << "(1= ya, 0= tidak)" << endl;
# cout << "=======================" << endl;
#
# return 0;
#
# }
# Out:
# Overwriting praktik_variabel.cpp

# %%
# !g++ praktik_variabel.cpp -o praktik_variabel
