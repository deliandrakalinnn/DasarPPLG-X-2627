# %% [markdown]
# <a href="https://colab.research.google.com/github/deliandrakalinnn/DasarPPLG-X-2627/blob/main/tugas_program_menghitung_keliling_persegi_panjang.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TUGAS MENGHITUNG BANGUN DATAR KELILING PERSEGI PANJANG
#
# Nama Kelompok: Nova crew
#
# 1.afra
# 2.delia
# 3.dava
# 4.iki
# 5.azril
# 6.rafa
# 7.dian

# %%
# !g++ --version
# Out:
# g++ (Ubuntu 13.3.0-6ubuntu2~24.04.1) 13.3.0
# Copyright (C) 2023 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# %%writefile kelilingpersegipanjang.cpp
# #include <iostream>
# using namespace std;
# int main ()
# {
#
# int p,l,keliling;
# cout<<"massukan panjang"<<endl;
# cin>>p;
# cout<<"massukan lebar"<<endl;
# cin>>l;
#
# keliling=2*p+l;
#
# cout<<"tampilkan keliling persegi panjang :"<<keliling<<endl;
# return 0;
# }
# Out:
# Overwriting kelilingpersegipanjang.cpp

# %%
# !g++ kelilingpersegipanjang.cpp -o main

# %%
# !./main
# Out:
# massukan panjang
# 30
# massukan lebar
# 20
# tampilkan keliling persegi panjang :80
